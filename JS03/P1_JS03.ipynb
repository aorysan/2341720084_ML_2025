# %% [markdown]
# ## Aryo Adi Putro - 2341720084
# ## TI-3G

# %%
try:
  import gdown
except ImportError:
  # !pip install gdown
  import gdown

gdown.download(id='1_drwRI2I8wLGNUgTRvmEZ-IAJJvCm8_5', output='Titanic-Dataset.csv', quiet=False)
gdown.download(id='1oKCPUN-nJ_EUKgLMLVEYWR47Qd8qBcXo', output='Titanic-Dataset-fixed.csv', quiet=False)
gdown.download(id='1zWjQID6M-z-XUK0dA3bB9bFfmw0SoJaZ', output='Titanic-Dataset-selected.csv', quiet=False)
gdown.download(id='1vpxNdBo2a7kPqEMIdmKi3IgSoWa2ifDb', output='lenna.png', quiet=False)

IMG_PATHS = ["Titanic-Dataset.csv", "Titanic-Dataset-fixed", "Titanic-Dataset-selected", "lenna.png"]
# Out:
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: beautifulsoup4 in d:\python\lib\site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in d:\python\lib\site-packages (from gdown) (3.17.0)
# Requirement already satisfied: requests[socks] in d:\python\lib\site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in d:\python\lib\site-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in d:\python\lib\site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\python\lib\site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in d:\python\lib\site-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\python\lib\site-packages (from requests[socks]->gdown) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in d:\python\lib\site-packages (from requests[socks]->gdown) (2025.4.26)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in d:\python\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in d:\python\lib\site-packages (from tqdm->gdown) (0.4.6)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Installing collected packages: gdown
# Successfully installed gdown-5.2.0
# Downloading...
# From: https://drive.google.com/uc?id=1_drwRI2I8wLGNUgTRvmEZ-IAJJvCm8_5
# To: d:\AryokPunya\Kuliah\Tugas\smt5\ML\2341720084_ML_2025\JS03\Titanic-Dataset.csv
# 100%|██████████| 61.2k/61.2k [00:00<00:00, 1.33MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1oKCPUN-nJ_EUKgLMLVEYWR47Qd8qBcXo
# To: d:\AryokPunya\Kuliah\Tugas\smt5\ML\2341720084_ML_2025\JS03\Titanic-Dataset-fixed.csv
# 100%|██████████| 67.8k/67.8k [00:00<00:00, 1.07MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1zWjQID6M-z-XUK0dA3bB9bFfmw0SoJaZ
# To: d:\AryokPunya\Kuliah\Tugas\smt5\ML\2341720084_ML_2025\JS03\Titanic-Dataset-selected.csv
# 100%|██████████| 23.5k/23.5k [00:00<00:00, 787kB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1vpxNdBo2a7kPqEMIdmKi3IgSoWa2ifDb
# To: d:\AryokPunya\Kuliah\Tugas\smt5\ML\2341720084_ML_2025\JS03\lenna.png
# 100%|██████████| 474k/474k [00:00<00:00, 1.62MB/s]

# %%
import pandas as pd
import pandas as pd
import io
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

data = 'Titanic-Dataset.csv' # path dataset
df = pd.read_csv(data) # load dataset

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Age - mean
df['Age'].fillna(value=df['Age'].mean(), inplace=True)

# Cabin - "DECK"
df['Cabin'].fillna(value="DECK", inplace=True)

# Embarked - modus
df['Embarked'].fillna(value=df['Embarked'].mode, inplace=True)
# Out:
# C:\Users\Aorys\AppData\Local\Temp\ipykernel_3380\220269673.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(value=df['Age'].mean(), inplace=True)
# C:\Users\Aorys\AppData\Local\Temp\ipykernel_3380\220269673.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Cabin'].fillna(value="DECK", inplace=True)

# %%
# === EKSTRAKSI FITUR ===

# 1. FamilySize: jumlah keluarga di kapal (SibSp + Parch + diri sendiri)
df["FamilySize"] = df["SibSp"] + df["Parch"] + 1

# 2. Title: ambil gelar dari kolom Name (Mr, Mrs, Miss, Master, dll.)
df["Title"] = df["Name"].str.extract(r',\s*([^\.]+)\.', expand=False)
title_mapping = {
    "Mlle": "Miss", "Ms": "Miss", "Mme": "Mrs",
    "Lady": "Rare", "Countess": "Rare", "Capt": "Rare", "Col": "Rare",
    "Don": "Rare", "Dr": "Rare", "Major": "Rare", "Rev": "Rare",
    "Sir": "Rare", "Jonkheer": "Rare", "Dona": "Rare"
}
df["Title"] = df["Title"].replace(title_mapping)

# 3. AgeBin: kelompokkan usia menjadi kategori
df["AgeBin"] = pd.cut(df["Age"], bins=[0, 12, 18, 35, 60, 100],
                      labels=["Child", "Teen", "YoungAdult", "Adult", "Senior"])

# 4. CabinDeck: ambil huruf pertama dari kolom Cabin
df["CabinDeck"] = df["Cabin"].astype(str).str[0]

# 5. Fare per person: bagi harga tiket dengan jumlah keluarga
df["FarePerPerson"] = df["Fare"] / df["FamilySize"]

print("✅ Hasil Ekstraksi fitur ")
df[["Name", "Title", "Age", "AgeBin", "FamilySize", "Cabin", "CabinDeck", "FarePerPerson"]].head()
# Out:
# ✅ Hasil Ekstraksi fitur
#                                                 Name Title   Age      AgeBin  \
# 0                            Braund, Mr. Owen Harris    Mr  22.0  YoungAdult
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...   Mrs  38.0       Adult
# 2                             Heikkinen, Miss. Laina  Miss  26.0  YoungAdult
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)   Mrs  35.0  YoungAdult
# 4                           Allen, Mr. William Henry    Mr  35.0  YoungAdult
#
#    FamilySize Cabin CabinDeck  FarePerPerson
# 0           2  DECK         D        3.62500
# 1           2   C85         C       35.64165
# 2           1  DECK         D        7.92500
# 3           2  C123         C       26.55000
# 4           1  DECK         D        8.05000

# %%
plt.figure(figsize=(12, 6))
sns.barplot(x="FamilySize", y="Survived", data=df)
plt.title("Survival Rate berdasarkan Family Size")
plt.show()

plt.figure(figsize=(12, 6))
sns.barplot(x="Title", y="Survived", data=df,
            order=df.groupby("Title")["Survived"].mean().sort_values().index)
plt.title("Survival Rate berdasarkan Title")
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(12, 6))
sns.barplot(x="AgeBin", y="Survived", data=df,
            order=["Child", "Teen", "YoungAdult", "Adult", "Senior"])
plt.title("Survival Rate berdasarkan Kelompok Usia (AgeBin)")
plt.show()

plt.figure(figsize=(12, 6))
sns.barplot(x="CabinDeck", y="Survived", data=df,
            order=df.groupby("CabinDeck")["Survived"].mean().sort_values().index)
plt.title("Survival Rate berdasarkan Cabin Deck")
plt.show()
